# %% [markdown]
# # NLP Lab: Introduction to Text Processing
#
# Welcome to the NLP Lab! In this notebook, you will learn the basics of Natural Language Processing using Python.
#
# ## 1. String Manipulation
# Let's start with basic string operations.

# %%
text = "Hello, welcome to SOVAP CyberLabs!"
print(text.lower())

# %% [markdown]
# ### Challenge 1
# Try to convert the text to uppercase.

# %%
# Your code here
