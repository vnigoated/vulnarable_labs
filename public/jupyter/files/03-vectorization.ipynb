# %% [markdown]
# # Lab 3: Vectorization (Enhanced)
#
# ## Introduction
# Visualizing the sparse matrix of Bag-of-Words and TF-IDF can help understand the sparsity.

# %%
# %pip install scikit-learn matplotlib pandas seaborn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer

corpus = [
    'This is the first document.',
    'This document is the second document.',
    'And this is the third one.',
    'Is this the first document?'
]

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(corpus)

# Convert to DataFrame for visualization
df_bow = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())

plt.figure(figsize=(10, 4))
sns.heatmap(df_bow, annot=True, cmap="YlGnBu", cbar=False)
plt.title("Bag of Words Heatmap")
plt.show()
